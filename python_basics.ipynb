# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshaya-14-KA/Data-Science-Basics/blob/main/python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
3+4
# Out:
# 7

# %%
import pandas as pd

# %%
df=pd.read_csv('Salaries.csv')

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.shape
# Out:
# (78, 6)

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
# prompt: can you use the head function on my data and tell me the first 5 records in the dataset

print(df.head(10))
df.head(5)
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
# prompt: can you find out the shape of the above data set
# can you tell me about what are teh names of the columns in this  dataset

print(df.shape)
df.columns
# Out:
# (78, 6)
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.mean(numeric_only=True)
# Out:
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
df['salary']
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
df['salary'].mean()
# Out:
# np.float64(108023.78205128205)

# %%
# prompt: i want to select salary and service from the above dataset

df[['salary','service']]
# Out:
#     salary  service
# 0   186960       49
# 1    93000        6
# 2   110515       20
# 3   131205       31
# 4   104800       18
# ..     ...      ...
# 73  105450       10
# 74  104542        6
# 75  124312       17
# 76  109954       14
# 77  109646       15
#
# [78 rows x 2 columns]

# %%
# prompt: i want to generate mean, median, standard deviation from salary column

# Mean of the 'salary' column
mean_salary = df['salary'].mean()
print(f"Mean Salary: {mean_salary}")

# Median of the 'salary' column
median_salary = df['salary'].median()
print(f"Median Salary: {median_salary}")

# Standard deviation of the 'salary' column
std_dev_salary = df['salary'].std()
print(f"Standard Deviation of Salary: {std_dev_salary}")
# Out:
# Mean Salary: 108023.78205128205
# Median Salary: 104671.0
# Standard Deviation of Salary: 28293.661022264165

# %%
df['salary'].skew()
# Out:
# np.float64(0.45210256755588096)

# %%
df['salary'].kurt()
# Out:
# np.float64(-0.4017126758820546)

# %%
df.isnull()
# Out:
#      rank  discipline    phd  service    sex  salary
# 0   False       False  False    False  False   False
# 1   False       False  False    False  False   False
# 2   False       False  False    False  False   False
# 3   False       False  False    False  False   False
# 4   False       False  False    False  False   False
# ..    ...         ...    ...      ...    ...     ...
# 73  False       False  False    False  False   False
# 74  False       False  False    False  False   False
# 75  False       False  False    False  False   False
# 76  False       False  False    False  False   False
# 77  False       False  False    False  False   False
#
# [78 rows x 6 columns]

# %%
pd.set_option('display.max_rows', None)

# %%
df.isnull()
# Out:
#      rank  discipline    phd  service    sex  salary
# 0   False       False  False    False  False   False
# 1   False       False  False    False  False   False
# 2   False       False  False    False  False   False
# 3   False       False  False    False  False   False
# 4   False       False  False    False  False   False
# 5   False       False  False    False  False   False
# 6   False       False  False    False  False   False
# 7   False       False  False    False  False   False
# 8   False       False  False    False  False   False
# 9   False       False  False    False  False   False
# 10  False       False  False    False  False   False
# 11  False       False  False    False  False   False
# 12  False       False  False    False  False   False
# 13  False       False  False    False  False   False
# 14  False       False  False    False  False   False
# 15  False       False  False    False  False   False
# 16  False       False  False    False  False   False
# ...

# %%
df.isnull().sum()
# Out:
# rank          0
# discipline    0
# phd           0
# service       0
# sex           0
# salary        0
# dtype: int64

# %%
df.iloc[:,:]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.iloc[0:10,:]
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
df.iloc[0:10,0:3]
# Out:
#         rank discipline  phd
# 0       Prof          B   56
# 1       Prof          A   12
# 2       Prof          A   23
# 3       Prof          A   40
# 4       Prof          B   20
# 5       Prof          A   20
# 6  AssocProf          A   20
# 7       Prof          A   18
# 8       Prof          A   29
# 9       Prof          A   51

# %%
df.iloc[:,:]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.iloc[0:10,]
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv('Universities.csv')

# %%
df1
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
plt.hist(df1['SAT'])
plt.xlabel('SAT Score')
plt.ylabel('Frequency')
plt.title('Distribution of SAT Scores')
plt.show()

# %%
sns.scatterplot(data=df1, y='SAT', x=df1.index,color='brown')
plt.xlabel('Index')
plt.ylabel('SAT Score')
plt.title('Scatter Plot of SAT Scores')
plt.show()

# %%
sns.histplot(df1['SAT'])
plt.show()

# %%
sns.histplot(df1['Accept'],color='orange')
plt.xlabel('Acceptance Rate')
plt.ylabel('Frequency')
plt.title('Distribution of Acceptance Rates')
plt.show()

# %%
plt.plot(df1['SAT'],df1['Accept'],'bo')
plt.xlabel('SAT Score')
plt.ylabel('Acceptance Rate')
plt.title('Scatter Plot of SAT Scores vs. Acceptance Rates')
plt.show()

# %%
plt.plot(df1['SAT'],df1['Top10'],'go')
plt.xlabel('SAT Score')
plt.ylabel('Acceptance Rate')
plt.title('Scatter Plot of SAT Scores vs. Acceptance Rates')
plt.show()

# %%
plt.plot(df1['SAT'],df1['Top10'],'bv')
plt.xlabel('SAT Score')
plt.ylabel('Top 10% High School Grad Rate')
plt.title('Scatter Plot of SAT Scores vs. Top 10%')
plt.show()

# %%
sns.pairplot(df1)
plt.show()

# %%
sns.pairplot(df1.iloc[:,1:3])
plt.show()

# %%
plt.boxplot(df1['SAT'])
plt.show()
